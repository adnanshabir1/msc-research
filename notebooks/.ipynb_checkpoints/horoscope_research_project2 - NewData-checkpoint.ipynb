# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# DataSource: https://www.kaggle.com/datasets/adxie12/horoscopes?select=horoscopes_scraped_2025.csv
# Load dataset (fixing the path)
df = pd.read_csv("../data/horoscope_saved_general.csv")

# Preview dataset
df.head()
# Out:
#     sign category      date                                          horoscope
# 0  aries  general  20241111  You're usually full of energy, Aries, but toda...
# 1  aries  general  20241112  If you've been working toward manifesting extr...
# 2  aries  general  20241113  A group of people oriented toward artistic, sp...
# 3  aries  general  20241114  You may find today that people are really attr...
# 4  aries  general  20241115  If your partner acts quickly on his or her pas...

# %% [markdown]
# #### Understand the Dataset

# %%
# Dataset shape
print("Shape:", df.shape)

# Column names
print("\nColumns:")
print(df.columns)

# Data types
print("\nData Types:")
print(df.dtypes)

# First 5 rows
print("\nSample Data:")
display(df.head())

# Missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Shape: (4392, 4)
#
# Columns:
# Index(['sign', 'category', 'date', 'horoscope'], dtype='object')
#
# Data Types:
# sign         object
# category     object
# date          int64
# horoscope    object
# dtype: object
#
# Sample Data:
#     sign category      date                                          horoscope
# 0  aries  general  20241111  You're usually full of energy, Aries, but toda...
# 1  aries  general  20241112  If you've been working toward manifesting extr...
# 2  aries  general  20241113  A group of people oriented toward artistic, sp...
# 3  aries  general  20241114  You may find today that people are really attr...
# 4  aries  general  20241115  If your partner acts quickly on his or her pas...
# Missing Values:
# sign         0
# category     0
# date         0
# horoscope    0
# dtype: int64

# %%
# General information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4392 entries, 0 to 4391
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sign       4392 non-null   object
#  1   category   4392 non-null   object
#  2   date       4392 non-null   int64
#  3   horoscope  4392 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 137.4+ KB

# %%
# Basic statistics
df.describe(include='all')
# Out:
#          sign category          date  \
# count    4392     4392  4.392000e+03
# unique     12        1           NaN
# top     aries  general           NaN
# freq      366     4392           NaN
# mean      NaN      NaN  2.024925e+07
# std       NaN      NaN  3.296686e+03
# min       NaN      NaN  2.024111e+07
# 25%       NaN      NaN  2.025021e+07
# 50%       NaN      NaN  2.025051e+07
# 75%       NaN      NaN  2.025081e+07
# max       NaN      NaN  2.025111e+07
#
#                                                 horoscope
# count                                                4392
# unique                                               4392
# top     The annoying restlessness that you experience ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %% [markdown]
# #### Convert Dates Properly

# %%
df["date"] = pd.to_datetime(df["date"], format="%Y%m%d")

# %%
df.head()
# Out:
#     sign category       date  \
# 0  aries  general 2024-11-11
# 1  aries  general 2024-11-12
# 2  aries  general 2024-11-13
# 3  aries  general 2024-11-14
# 4  aries  general 2024-11-15
#
#                                            horoscope
# 0  You're usually full of energy, Aries, but toda...
# 1  If you've been working toward manifesting extr...
# 2  A group of people oriented toward artistic, sp...
# 3  You may find today that people are really attr...
# 4  If your partner acts quickly on his or her pas...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4392 entries, 0 to 4391
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sign       4392 non-null   object
#  1   category   4392 non-null   object
#  2   date       4392 non-null   datetime64[ns]
#  3   horoscope  4392 non-null   object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 137.4+ KB

# %%
df["category"].value_counts()
# Out:
# category
# general    4392
# Name: count, dtype: int64

# %%
print(df["date"].min())
print(df["date"].max())
# Out:
# 2024-11-10 00:00:00
# 2025-11-10 00:00:00

# %% [markdown]
# #### Add Mercury Retrograde Labels

# %%
# Mercury retrograde periods between 2024-11-10 and 2025-11-10
retrograde_periods = [
    # 2024
    ('2024-11-25', '2024-12-15'),
    
    # 2025
    ('2025-03-15', '2025-04-07'),
    ('2025-07-18', '2025-08-11'),
    ('2025-11-09', '2025-11-29'),
]

# %%
# Function to check if a date falls in retrograde
def is_retrograde(date):
    for start, end in retrograde_periods:
        if pd.to_datetime(start) <= date <= pd.to_datetime(end):
            return 1
    return 0

# %%
# Apply the function
df['retrograde'] = df['date'].apply(is_retrograde)

# %%
# Check result
df[['date', 'retrograde']].head(10)
# Out:
#         date  retrograde
# 0 2024-11-11           0
# 1 2024-11-12           0
# 2 2024-11-13           0
# 3 2024-11-14           0
# 4 2024-11-15           0
# 5 2024-11-16           0
# 6 2024-11-17           0
# 7 2024-11-18           0
# 8 2024-11-19           0
# 9 2024-11-20           0

# %%
df["retrograde"].value_counts()
# Out:
# retrograde
# 0    3528
# 1     864
# Name: count, dtype: int64

# %% [markdown]
# #### Clean the Horoscope Text

# %%
import re  # regular expressions (used for text cleaning)

# Define a cleaning function
def clean_text(text):
    text = text.lower()                    # convert all text to lowercase
    text = re.sub(r'[^\w\s]', '', text)    # remove punctuation
    return text

# %%
# Apply the function to create a new column
df['clean_horoscope'] = df['horoscope'].apply(clean_text)

# View results
df[['horoscope', 'clean_horoscope']].head()
# Out:
#                                            horoscope  \
# 0  You're usually full of energy, Aries, but toda...
# 1  If you've been working toward manifesting extr...
# 2  A group of people oriented toward artistic, sp...
# 3  You may find today that people are really attr...
# 4  If your partner acts quickly on his or her pas...
#
#                                      clean_horoscope
# 0  youre usually full of energy aries but today y...
# 1  if youve been working toward manifesting extra...
# 2  a group of people oriented toward artistic spi...
# 3  you may find today that people are really attr...
# 4  if your partner acts quickly on his or her pas...

# %% [markdown]
# #### VADER

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
# Download VADER lexicon (only once)
# nltk.download('vader_lexicon')

# %%
# Create a sentiment analyzer object
sia = SentimentIntensityAnalyzer()

# %%
# Example text
text = "Today you will feel happy and achieve great success."

# Get sentiment scores
scores = sia.polarity_scores(text)

# Print results
print(scores)
# Out:
# {'neg': 0.0, 'neu': 0.343, 'pos': 0.657, 'compound': 0.91}

# %%
text2 = "Today will bring difficulties and misunderstandings."

print(sia.polarity_scores(text2))
# Out:
# {'neg': 0.306, 'neu': 0.694, 'pos': 0.0, 'compound': -0.296}

# %%
# Apply sentiment analysis to clean_text

# Create a new column for sentiment scores
df['sentiment'] = df['clean_horoscope'].apply(lambda x: sia.polarity_scores(x)['compound'])

# %%
# View results
df.head()
# Out:
#     sign category       date  \
# 0  aries  general 2024-11-11
# 1  aries  general 2024-11-12
# 2  aries  general 2024-11-13
# 3  aries  general 2024-11-14
# 4  aries  general 2024-11-15
#
#                                            horoscope  retrograde  \
# 0  You're usually full of energy, Aries, but toda...           0
# 1  If you've been working toward manifesting extr...           0
# 2  A group of people oriented toward artistic, sp...           0
# 3  You may find today that people are really attr...           0
# 4  If your partner acts quickly on his or her pas...           0
#
#                                      clean_horoscope  sentiment
# 0  youre usually full of energy aries but today y...     0.8760
# 1  if youve been working toward manifesting extra...     0.9136
# 2  a group of people oriented toward artistic spi...     0.9509
# 3  you may find today that people are really attr...     0.9020
# 4  if your partner acts quickly on his or her pas...     0.9011

# %% [markdown]
# ##### Convert Sentiment Into Categories

# %%
# Function to classify sentiment
def classify_sentiment(score):
    if score >= 0.05:
        return "positive"
    elif score <= -0.05:
        return "negative"
    else:
        return "neutral"

# Apply classification
df['sentiment_label'] = df['sentiment'].apply(classify_sentiment)

# View results
df[['sentiment', 'sentiment_label']].head()
# Out:
#    sentiment sentiment_label
# 0     0.8760        positive
# 1     0.9136        positive
# 2     0.9509        positive
# 3     0.9020        positive
# 4     0.9011        positive

# %% [markdown]
# ##### Analyze Sentiment Distribution

# %%
# Count how many of each sentiment type
sentiment_counts = df['sentiment_label'].value_counts()

print(sentiment_counts)
# Out:
# sentiment_label
# positive    3637
# negative     673
# neutral       82
# Name: count, dtype: int64

# %%
# Convert counts to percentage
sentiment_percent = df['sentiment_label'].value_counts(normalize=True) * 100

print(sentiment_percent)
# Out:
# sentiment_label
# positive    82.809654
# negative    15.323315
# neutral      1.867031
# Name: proportion, dtype: float64

# %% [markdown]
# ##### Compare Sentiment (Retrograde vs Normal)

# %%
# Count how many of each sentiment type group by retrograde
retrograde_sentiment_counts = df.groupby('retrograde')['sentiment_label'].value_counts()

print(retrograde_sentiment_counts)
# Out:
# retrograde  sentiment_label
# 0           positive           2934
#             negative            528
#             neutral              66
# 1           positive            703
#             negative            145
#             neutral              16
# Name: count, dtype: int64

# %%
# Calculate average sentiment for each group
sentiment_comparison = df.groupby('retrograde')['sentiment'].mean()

print(sentiment_comparison)
# Out:
# retrograde
# 0    0.572056
# 1    0.548348
# Name: sentiment, dtype: float64

# %%
# Plot comparison
sns.boxplot(x='retrograde', y='sentiment', data=df)

plt.title("Sentiment Distribution: Retrograde vs Normal")
plt.xlabel("Retrograde (0 = No, 1 = Yes)")
plt.ylabel("Sentiment Score")

plt.show()

# %% [markdown]
# #### RoBERTa

# %%
from transformers import pipeline
import torch

# %%
sentiment_model = pipeline(
    "sentiment-analysis",
    model="cardiffnlp/twitter-roberta-base-sentiment-latest"
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# RobertaForSequenceClassification LOAD REPORT from: cardiffnlp/twitter-roberta-base-sentiment-latest
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.pooler.dense.bias       | UNEXPECTED |  |
# roberta.embeddings.position_ids | UNEXPECTED |  |
# roberta.pooler.dense.weight     | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
sample_text = df["horoscope"].iloc[0]

sentiment_model(sample_text)
# Out:
# [{'label': 'positive', 'score': 0.4869808852672577}]

# %%
def get_sentiment(text):
    result = sentiment_model(text[:512])[0]  # limit text length for safety
    return result["label"], result["score"]

# %%
get_sentiment(df["horoscope"].iloc[0])
# Out:
# ('positive', 0.4869808852672577)

# %%
# testing the process on first 100 rows initially
sample_df = df.head(100).copy()

sample_df["sentiment"] = sample_df["horoscope"].apply(get_sentiment)

sample_df.head()
# Out:
#     sign category       date  \
# 0  aries  general 2024-11-11
# 1  aries  general 2024-11-12
# 2  aries  general 2024-11-13
# 3  aries  general 2024-11-14
# 4  aries  general 2024-11-15
#
#                                            horoscope  retrograde  \
# 0  You're usually full of energy, Aries, but toda...           0
# 1  If you've been working toward manifesting extr...           0
# 2  A group of people oriented toward artistic, sp...           0
# 3  You may find today that people are really attr...           0
# 4  If your partner acts quickly on his or her pas...           0
#
#                                      clean_horoscope  \
# 0  youre usually full of energy aries but today y...
# 1  if youve been working toward manifesting extra...
# 2  a group of people oriented toward artistic spi...
# 3  you may find today that people are really attr...
# 4  if your partner acts quickly on his or her pas...
#
#                         sentiment sentiment_label
# 0  (positive, 0.4869808852672577)        positive
# 1  (positive, 0.9288892149925232)        positive
# 2  (positive, 0.8904693126678467)        positive
# 3  (positive, 0.9030788540840149)        positive
# 4   (neutral, 0.5961227416992188)        positive

# %%
sample_df["sentiment_label"] = sample_df["sentiment"].apply(lambda x: x[0])
sample_df["sentiment_score"] = sample_df["sentiment"].apply(lambda x: x[1])

sample_df.drop(columns=["sentiment"], inplace=True)

sample_df.head()
# Out:
#     sign category       date  \
# 0  aries  general 2024-11-11
# 1  aries  general 2024-11-12
# 2  aries  general 2024-11-13
# 3  aries  general 2024-11-14
# 4  aries  general 2024-11-15
#
#                                            horoscope  retrograde  \
# 0  You're usually full of energy, Aries, but toda...           0
# 1  If you've been working toward manifesting extr...           0
# 2  A group of people oriented toward artistic, sp...           0
# 3  You may find today that people are really attr...           0
# 4  If your partner acts quickly on his or her pas...           0
#
#                                      clean_horoscope sentiment_label  \
# 0  youre usually full of energy aries but today y...        positive
# 1  if youve been working toward manifesting extra...        positive
# 2  a group of people oriented toward artistic spi...        positive
# 3  you may find today that people are really attr...        positive
# 4  if your partner acts quickly on his or her pas...         neutral
#
#    sentiment_score
# 0         0.486981
# 1         0.928889
# 2         0.890469
# 3         0.903079
# 4         0.596123

# %%
# clearing these columns before running the model on all rows
df["sentiment_label"] = None
df["sentiment_score"] = None

# %%
batch_size = 500

for i in range(0, len(df), batch_size):
    batch = df.iloc[i:i+batch_size].copy()
    
    results = batch["horoscope"].apply(get_sentiment)
    
    df.loc[batch.index, "sentiment_label"] = results.apply(lambda x: x[0])
    df.loc[batch.index, "sentiment_score"] = results.apply(lambda x: x[1])
    
    print(f"Processed: {i} to {i+batch_size}")
# Out:
# Processed: 0 to 500
# Processed: 500 to 1000
# Processed: 1000 to 1500
# Processed: 1500 to 2000
# Processed: 2000 to 2500
# Processed: 2500 to 3000
# Processed: 3000 to 3500
# Processed: 3500 to 4000
# Processed: 4000 to 4500

# %% [markdown]
# Due to computational constraints of transformer-based models, sentiment extraction was performed in batches to optimize memory usage and ensure stability.

# %%
def convert_sentiment(label, score):
    if label.lower() == "positive":
        return score
    elif label.lower() == "negative":
        return -score
    else:
        return 0

# %%
df.head()
# Out:
#     sign category       date  \
# 0  aries  general 2024-11-11
# 1  aries  general 2024-11-12
# 2  aries  general 2024-11-13
# 3  aries  general 2024-11-14
# 4  aries  general 2024-11-15
#
#                                            horoscope  retrograde  \
# 0  You're usually full of energy, Aries, but toda...           0
# 1  If you've been working toward manifesting extr...           0
# 2  A group of people oriented toward artistic, sp...           0
# 3  You may find today that people are really attr...           0
# 4  If your partner acts quickly on his or her pas...           0
#
#                                      clean_horoscope  sentiment  \
# 0  youre usually full of energy aries but today y...     0.8760
# 1  if youve been working toward manifesting extra...     0.9136
# 2  a group of people oriented toward artistic spi...     0.9509
# 3  you may find today that people are really attr...     0.9020
# 4  if your partner acts quickly on his or her pas...     0.9011
#
#   sentiment_label sentiment_score
# 0        positive        0.486981
# 1        positive        0.928889
# 2        positive        0.890469
# 3        positive        0.903079
# 4         neutral        0.596123

# %%
df["sentiment_numeric"] = df.apply(
    lambda x: convert_sentiment(x["sentiment_label"], x["sentiment_score"]),
    axis=1
)

# %%
df.head()
# Out:
#     sign category       date  \
# 0  aries  general 2024-11-11
# 1  aries  general 2024-11-12
# 2  aries  general 2024-11-13
# 3  aries  general 2024-11-14
# 4  aries  general 2024-11-15
#
#                                            horoscope  retrograde  \
# 0  You're usually full of energy, Aries, but toda...           0
# 1  If you've been working toward manifesting extr...           0
# 2  A group of people oriented toward artistic, sp...           0
# 3  You may find today that people are really attr...           0
# 4  If your partner acts quickly on his or her pas...           0
#
#                                      clean_horoscope  sentiment  \
# 0  youre usually full of energy aries but today y...     0.8760
# 1  if youve been working toward manifesting extra...     0.9136
# 2  a group of people oriented toward artistic spi...     0.9509
# 3  you may find today that people are really attr...     0.9020
# 4  if your partner acts quickly on his or her pas...     0.9011
#
#   sentiment_label sentiment_score  sentiment_numeric
# 0        positive        0.486981           0.486981
# 1        positive        0.928889           0.928889
# 2        positive        0.890469           0.890469
# 3        positive        0.903079           0.903079
# 4         neutral        0.596123           0.000000

# %%
df.groupby("retrograde")["sentiment_numeric"].mean()
# Out:
# retrograde
# 0    0.335687
# 1    0.321416
# Name: sentiment_numeric, dtype: float64

# %% [markdown]
# Horoscopes are slightly more negative during Mercury retrograde, but the difference is extremely small.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.boxplot(x="retrograde", y="sentiment_numeric", data=df)
plt.title("Sentiment Comparison: Retrograde vs Normal Periods")
plt.show()
